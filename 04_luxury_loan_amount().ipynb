# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
# %run 01_luxury_loan_amount(monovariable_analysis).ipynb
df_processed
# Out:
#       funded_amount funded_date  duration years  duration months  \
# 0          790000.0  2012-04-27              20              240
# 1         1720000.0  2014-10-14              15              180
# 3         1079000.0  2012-02-23              20              240
# 4         2028000.0  2016-04-01              20              240
# 5          612000.0  2017-10-26              20              240
# ...             ...         ...             ...              ...
# 1673       528000.0  2012-11-10              20              240
# 1674       885000.0  2015-08-16              20              240
# 1675      1530000.0  2014-09-01              20              240
# 1676       897000.0  2014-02-14              15              180
# 1677      1656000.0  2016-07-12              15              180
#
#       10 yr treasury index date funded  interest rate  payments  \
# 0                               1.9600        0.03359   4524.65
# ...

# %%
#BUILDING CLASS AT PRESENT (R1) 
df_BCAT = df_processed['BUILDING CLASS AT PRESENT']=='R1'
df_BCAT_1 = df_processed[df_BCAT]
df_BCAT_1
# Out:
#       funded_amount funded_date  duration years  duration months  \
# 0          790000.0  2012-04-27              20              240
# 3         1079000.0  2012-02-23              20              240
# 6          630000.0  2017-12-07              15              180
# 7          795000.0  2017-10-06              20              240
# 8         2004000.0  2019-10-12              15              180
# ...             ...         ...             ...              ...
# 1644       448000.0  2017-02-07              30              360
# 1656      1580000.0  2014-01-16              15              180
# 1665       649000.0  2017-08-03              20              240
# 1670      2052000.0  2015-11-08              15              180
# 1671       580000.0  2012-09-14              20              240
#
#       10 yr treasury index date funded  interest rate  payments  \
# 0                               1.9600        0.03359   4524.65
# ...

# %%
df_numerical = df_processed[['funded_amount', 'duration months', '10 yr treasury index date funded', 'interest rate', 'total past payments', 'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'TAX CLASS AT TIME OF SALE', 'property value', 'loan balance']]
df_numerical
# Out:
#       funded_amount  duration months  10 yr treasury index date funded  \
# 0          790000.0              240                            1.9600
# 1         1720000.0              180                            2.2100
# 3         1079000.0              240                            1.9900
# 4         2028000.0              240                            1.7900
# 5          612000.0              240                            2.4609
# ...             ...              ...                               ...
# 1673       528000.0              240                            1.6100
# 1674       885000.0              240                            2.2000
# 1675      1530000.0              240                            2.3500
# 1676       897000.0              180                            2.7500
# 1677      1656000.0              180                            1.5300
#
#       interest rate  total past payments LAND SQUARE FEET GROSS SQUARE FEET  \
# ...

# %%
plt.figure(figsize=(10,12))
df_numerical.corr()
sns.heatmap(df_numerical.corr(),annot=True)
plt.show()
# Out:
# C:\Users\Cristian Durango\AppData\Local\Temp\ipykernel_6560\1002148984.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_numerical.corr()
# C:\Users\Cristian Durango\AppData\Local\Temp\ipykernel_6560\1002148984.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_numerical.corr(),annot=True)

# %%
X_0 = df_numerical[['property value', 'loan balance','total past payments']]
y = df_numerical['funded_amount'].values.reshape(-1,1)

sc_x_0 = StandardScaler()
sc_y = StandardScaler()

x_std_0 = sc_x_0.fit_transform(X_0)
y_std = sc_y.fit_transform(y)

slr = LinearRegression()
slr.fit(x_std_0,y_std)

interest_rate = 0.03389
property_value = 2216500
loan_balance = 1513242.57
duration_months = 20*12
total_past_payments = 45
funded_amount = 2028000.0
payments = 11439.05
ten_yr_index = 1.79

funded_amount_std = sc_x_0.transform(np.array([property_value, loan_balance, total_past_payments]).reshape(-1,3))
sc_y.inverse_transform(slr.predict(funded_amount_std))
# Out:
# C:\Users\Cristian Durango\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[2054393.06054894]])
