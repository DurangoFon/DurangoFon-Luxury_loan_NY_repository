# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %run 01_luxury_loan_amount(monovariable_analysis).ipynb

# %% [markdown]
# heatmap

# %%
df_processed
# Out:
#       funded_amount funded_date  duration years  duration months  \
# 0          790000.0  2012-04-27              20              240
# 1         1720000.0  2014-10-14              15              180
# 3         1079000.0  2012-02-23              20              240
# 4         2028000.0  2016-04-01              20              240
# 5          612000.0  2017-10-26              20              240
# ...             ...         ...             ...              ...
# 1673       528000.0  2012-11-10              20              240
# 1674       885000.0  2015-08-16              20              240
# 1675      1530000.0  2014-09-01              20              240
# 1676       897000.0  2014-02-14              15              180
# 1677      1656000.0  2016-07-12              15              180
#
#       10 yr treasury index date funded  interest rate  payments  \
# 0                               1.9600        0.03359   4524.65
# 1                               2.2100        0.03508  12302.74
# 3                               1.9900        0.03389   6196.40
# 4                               1.7900        0.03188  11439.05
# 5                               2.4609        0.03860   3663.61
# ...                                ...            ...       ...
# 1673                            1.6100        0.03009   2930.65
# 1674                            2.2000        0.03599   5177.78
# 1675                            2.3500        0.03748   9069.60
# 1676                            2.7500        0.04049   6657.05
# 1677                            1.5300        0.02828  11299.54
#
#       total past payments  loan balance  property value purpose  \
# 0                      92     373732.18        930250.0    boat
# 1                      62     957230.24       1995250.0    boat
# 3                      94     496538.75       1402450.0    boat
# 4                      45    1513242.57       2216500.0    boat
# 5                      26     516746.19        711850.0    boat
# ...                   ...           ...             ...     ...
# 1673                   85     278894.35        778400.0   plane
# 1674                   52     615755.47       1084950.0   plane
# 1675                   64     949545.68       1627400.0   plane
# 1676                   70     431006.63       1184350.0   plane
# 1677                   41    1192718.78       1779400.0   plane
#
#                                      title  employment length  \
# 0     Vice President Global Field Services                  6
# 1                  Senior program manager                  10
# 3                            Vice presiden                 17
# 4                           Bank examiner                   5
# 5     Senior Director of Video Programming                  3
# ...                                    ...                ...
# 1673                       franchise owner                  3
# 1674               Chief Operating Officer                 13
# 1675                       Owner/physician                 10
# 1676                        General Manger                  5
# 1677       Vice President, Capital Markets                  8
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      15 CONDOS - 2-10 UNIT RESIDENTIAL                             2C
# 1      04 TAX CLASS 1 CONDOS                                         1A
# 3      15 CONDOS - 2-10 UNIT RESIDENTIAL                             2C
# 4      49 CONDO WAREHOUSES/FACTORY/INDUS                              4
# 5      07 RENTALS - WALKUP APARTMENTS                                2A
# ...                                            ...                  ...
# 1673   04 TAX CLASS 1 CONDOS                                         1C
# 1674   04 TAX CLASS 1 CONDOS                                         1C
# 1675   04 TAX CLASS 1 CONDOS                                         1C
# 1676  11A CONDO-RENTALS                                               2
# 1677   16 CONDOS - 2-10 UNIT WITH COMMERCIAL UNIT                    2C
#
#      BUILDING CLASS AT PRESENT  TOTAL UNITS LAND SQUARE FEET  \
# 0                           R1            1                0
# 1                           R3            1                0
# 3                           R1            1                0
# 4                           RW            1                0
# 5                           C3            4             3194
# ...                        ...          ...              ...
# 1673                        R6            1                0
# 1674                        R6            1                0
# 1675                        R6            1                0
# 1676                        RR           11                0
# 1677                        R8            1                0
#
#      GROSS SQUARE FEET  TAX CLASS AT TIME OF SALE
# 0                    0                          2
# 1                    0                          1
# 3                    0                          2
# 4                    0                          4
# 5                 3296                          2
# ...                ...                        ...
# 1673                 0                          1
# 1674                 0                          1
# 1675                 0                          1
# 1676             16376                          2
# 1677                 0                          2
#
# [1578 rows x 20 columns]

# %%
df_numerical = df_processed.drop(['duration months','purpose','BUILDING CLASS CATEGORY','title','BUILDING CLASS AT PRESENT','TAX CLASS AT TIME OF SALE'],axis=1)
df_numerical
# Out:
#       funded_amount funded_date  duration years  \
# 0          790000.0  2012-04-27              20
# 1         1720000.0  2014-10-14              15
# 3         1079000.0  2012-02-23              20
# 4         2028000.0  2016-04-01              20
# 5          612000.0  2017-10-26              20
# ...             ...         ...             ...
# 1673       528000.0  2012-11-10              20
# 1674       885000.0  2015-08-16              20
# 1675      1530000.0  2014-09-01              20
# 1676       897000.0  2014-02-14              15
# 1677      1656000.0  2016-07-12              15
#
#       10 yr treasury index date funded  interest rate  payments  \
# 0                               1.9600        0.03359   4524.65
# 1                               2.2100        0.03508  12302.74
# 3                               1.9900        0.03389   6196.40
# 4                               1.7900        0.03188  11439.05
# 5                               2.4609        0.03860   3663.61
# ...                                ...            ...       ...
# 1673                            1.6100        0.03009   2930.65
# 1674                            2.2000        0.03599   5177.78
# 1675                            2.3500        0.03748   9069.60
# 1676                            2.7500        0.04049   6657.05
# 1677                            1.5300        0.02828  11299.54
#
#       total past payments  loan balance  property value  employment length  \
# 0                      92     373732.18        930250.0                  6
# 1                      62     957230.24       1995250.0                 10
# 3                      94     496538.75       1402450.0                 17
# 4                      45    1513242.57       2216500.0                  5
# 5                      26     516746.19        711850.0                  3
# ...                   ...           ...             ...                ...
# 1673                   85     278894.35        778400.0                  3
# 1674                   52     615755.47       1084950.0                 13
# 1675                   64     949545.68       1627400.0                 10
# 1676                   70     431006.63       1184350.0                  5
# 1677                   41    1192718.78       1779400.0                  8
#
#      TAX CLASS AT PRESENT  TOTAL UNITS LAND SQUARE FEET GROSS SQUARE FEET
# 0                      2C            1                0                 0
# 1                      1A            1                0                 0
# 3                      2C            1                0                 0
# 4                       4            1                0                 0
# 5                      2A            4             3194              3296
# ...                   ...          ...              ...               ...
# 1673                   1C            1                0                 0
# 1674                   1C            1                0                 0
# 1675                   1C            1                0                 0
# 1676                    2           11                0             16376
# 1677                   2C            1                0                 0
#
# [1578 rows x 14 columns]

# %% [markdown]
# Correlation between variables

# %%
plt.figure(figsize=(16,18))
df_numerical.corr()
sns.heatmap(df_numerical.corr(),annot=True)
plt.show()
# Out:
# C:\Users\Cristian Durango\AppData\Local\Temp\ipykernel_5684\420717386.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_numerical.corr()
# C:\Users\Cristian Durango\AppData\Local\Temp\ipykernel_5684\420717386.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_numerical.corr(),annot=True)

# %%
sns.pairplot(data = df_processed)

# %%
sns.displot(data = df_processed,x='TAX CLASS AT PRESENT')

# %%
sns.displot(data = df_processed,x='TAX CLASS AT PRESENT',y='funded_amount',hue = 'TAX CLASS AT TIME OF SALE')

# %% [markdown]
# lineal (loan balance , funded amount)

# %%
sns.scatterplot(data = df_numerical,x = 'loan balance', y = 'funded_amount',hue='TAX CLASS AT PRESENT',alpha=0.3)
plt.show()

# %% [markdown]
# lineal (loan balance, property value, tax class)

# %%
sns.scatterplot(data = df_numerical,x = 'loan balance', y = 'property value',hue='TAX CLASS AT PRESENT')
# Out:
# <Axes: xlabel='loan balance', ylabel='property value'>

# %% [markdown]
# random forest(property value, tax class at present)

# %%
sns.scatterplot(data = df_processed,x = 'loan balance', y = 'property value',hue = 'TAX CLASS AT PRESENT')
# Out:
# <Axes: xlabel='loan balance', ylabel='property value'>

# %% [markdown]
# logistic (loan balance, tax class at preset)

# %%
sns.scatterplot(data = df_processed,x = 'loan balance', y = 'interest rate',hue = 'TAX CLASS AT PRESENT')
# Out:
# <Axes: xlabel='loan balance', ylabel='interest rate'>

# %% [markdown]
# cluster()

# %%
plt.figure(figsize=(16,30))
sns.displot(data = df_processed,x = 'loan balance', y = 'interest rate', hue = 'BUILDING CLASS CATEGORY')
plt.show()

# %% [markdown]
# logistic (payments,duration years)

# %%
plt.figure(figsize=(5,7))
sns.violinplot(data= df_processed,y = 'payments',x = 'duration years')
plt.show()

# %% [markdown]
# desicion tree (total past payments, interest rate)
# cluster (nb)

# %%
sns.scatterplot(data = df_processed,x='total past payments',y='interest rate',hue='purpose')
plt.legend(loc="center",bbox_to_anchor=(1.2,0.3))

# %% [markdown]
# forest tree(intrest rate, duration rate)

# %%
sns.violinplot(data = df_processed,y = 'interest rate', x = 'duration years',hue = 'TAX CLASS AT TIME OF SALE')
plt.show()

# %%
df_processed.describe()
# Out:
#        funded_amount  duration years  duration months  \
# count   1.578000e+03     1578.000000      1578.000000
# mean    1.573073e+06       27.357414       328.288973
# std     9.004410e+05        5.629685        67.556220
# min     4.400000e+05       10.000000       120.000000
# 25%     1.002375e+06       30.000000       360.000000
# 50%     1.460000e+06       30.000000       360.000000
# 75%     1.790000e+06       30.000000       360.000000
# max     1.050800e+07       30.000000       360.000000
#
#        10 yr treasury index date funded  interest rate       payments  \
# count                       1578.000000    1578.000000    1578.000000
# mean                           2.249708       0.037952    8089.954968
# std                            0.434574       0.004445    5466.344996
# min                            1.370000       0.027680    1900.780000
# 25%                            1.880000       0.034480    5118.220000
# 50%                            2.238750       0.037795    7145.870000
# 75%                            2.590000       0.041388    9024.682500
# max                            3.230000       0.048280  105486.810000
#
#        total past payments  loan balance  property value  employment length  \
# count          1578.000000  1.578000e+03    1.578000e+03        1578.000000
# mean             48.255387  1.164477e+06    1.738010e+06           9.302281
# std              28.347156  6.219452e+05    9.116372e+05           5.093471
# min               0.000000  1.978503e+05    4.732000e+05           1.000000
# 25%              23.000000  7.122941e+05    1.194225e+06           5.000000
# 50%              49.000000  1.071023e+06    1.613250e+06           9.000000
# 75%              73.000000  1.404093e+06    1.959775e+06          14.000000
# max              96.000000  3.482132e+06    1.080030e+07          18.000000
#
#        TOTAL UNITS  TAX CLASS AT TIME OF SALE
# count  1578.000000                1578.000000
# mean      2.720532                   1.858048
# std       4.340731                   0.672969
# min       0.000000                   1.000000
# 25%       1.000000                   1.000000
# 50%       1.000000                   2.000000
# 75%       4.000000                   2.000000
# max      72.000000                   4.000000

# %%
sns.violinplot(data = df_processed, x='TAX CLASS AT PRESENT', y='loan balance')
# Out:
# <Axes: xlabel='TAX CLASS AT PRESENT', ylabel='loan balance'>

# %%
sns.violinplot(data = df_processed, x='TAX CLASS AT PRESENT', y='duration years')
# Out:
# <Axes: xlabel='TAX CLASS AT PRESENT', ylabel='duration years'>

# %%
sns.violinplot(data= df_processed, y = 'purpose', x = 'TAX CLASS AT TIME OF SALE')
# Out:
# <Axes: xlabel='TAX CLASS AT TIME OF SALE', ylabel='purpose'>

# %%
sns.violinplot(data= df_processed, y = 'purpose', x = 'funded_amount')
# Out:
# <Axes: xlabel='funded_amount', ylabel='purpose'>
